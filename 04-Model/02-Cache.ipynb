# %% [markdown]
# ## 캐싱(Caching)
#
# LangChain은 LLM을 위한 선택적 캐싱 레이어를 제공합니다.
#
# 이는 두 가지 이유로 유용합니다.
#
# - 동일한 완료를 여러 번 요청하는 경우 LLM 공급자에 대한 **API 호출 횟수를 줄여 비용을 절감**할 수 있습니다.
# - LLM 제공업체에 대한 **API 호출 횟수를 줄여 애플리케이션의 속도를 높일 수** 있습니다.

# %%
# API KEY를 환경변수로 관리하기 위한 설정 파일
from dotenv import load_dotenv

# API KEY 정보로드
load_dotenv()
# Out:
# True

# %%
# LangSmith 추적을 설정합니다. https://smith.langchain.com
# !pip install langchain-teddynote
from langchain_teddynote import logging

# 프로젝트 이름을 입력합니다.
logging.langsmith("CH04-Models")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# CH04-Models

# %% [markdown]
# 모델과 프롬프트를 생성합니다

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate

# 모델을 생성합니다.
llm = ChatOpenAI(model_name="gpt-3.5-turbo")

# 프롬프트를 생성합니다.
prompt = PromptTemplate.from_template("{country} 에 대해서 200자 내외로 요약해줘")

# 체인을 생성합니다.
chain = prompt | llm

# %%
# %%time 
response = chain.invoke({"country": "한국"})
print(response.content)
# Out:
# 한국은 동아시아에 위치한 고도로 발전한 경제를 가진 나라로, 전통과 현대가 조화를 이루는 문화를 가지고 있다. 수도는 서울이며, 주요 도시로는 부산, 대구, 인천 등이 있다. 한국은 세계적으로 유명한 K-pop, K-drama 등의 문화 콘텐츠로 유명하며, 한류 열풍을 일으키고 있다. 또한 전통적인 음식인 김치, 불고기 등이 유명하다. 정치적으로는 북한과의 관계가 긴장되어 있지만, 국내는 안정적으로 발전하고 있으며, 선진국으로의 발전을 꾀하고 있다. 한반도의 독특한 역사와 문화를 지니고 있는 한국은 독자적이고 매력적인 나라이다.
# CPU times: user 4.09 ms, sys: 918 μs, total: 5 ms
# Wall time: 5.2 ms

# %% [markdown]
# ## InMemoryCache
#
# 인메모리 캐시를 사용하여 동일 질문에 대한 답변을 저장하고, 캐시에 저장된 답변을 반환합니다.

# %%
# %%time
from langchain.globals import set_llm_cache
from langchain.cache import InMemoryCache

# 인메모리 캐시를 사용합니다.
set_llm_cache(InMemoryCache())

# 체인을 실행합니다.
response = chain.invoke({"country": "한국"})
print(response.content)
# Out:
# 한국은 동아시아에 위치한 고도 경제성장을 이룩한 선진국가이다. 수도는 서울이며, 사람들은 고도로 발달한 과학기술과 문화를 자랑한다. 한류 열풍으로 전 세계에 한국 문화를 알리며 인기를 끌고 있다. 또한 K-pop, K-drama, K-beauty 등이 세계적인 트렌드로 자리 잡고 있다. 한반도에는 북한과의 군사적 긴장 상태가 지속되고 있지만, 남북한 간의 평화 협력을 위한 노력도 계속되고 있다. 한국은 높은 교육수준과 혁신적인 기술력을 갖춘 나라로, 세계적인 기업들과의 협력을 통해 경제적으로도 성장하고 있다.
# CPU times: user 18 ms, sys: 3.78 ms, total: 21.8 ms
# Wall time: 3.54 s

# %%
# %%time
# 체인을 실행합니다.
response = chain.invoke({"country": "한국"})
print(response.content)
# Out:
# 한국은 동아시아에 위치한 고도 경제성장을 이룩한 선진국가이다. 수도는 서울이며, 사람들은 고도로 발달한 과학기술과 문화를 자랑한다. 한류 열풍으로 전 세계에 한국 문화를 알리며 인기를 끌고 있다. 또한 K-pop, K-drama, K-beauty 등이 세계적인 트렌드로 자리 잡고 있다. 한반도에는 북한과의 군사적 긴장 상태가 지속되고 있지만, 남북한 간의 평화 협력을 위한 노력도 계속되고 있다. 한국은 높은 교육수준과 혁신적인 기술력을 갖춘 나라로, 세계적인 기업들과의 협력을 통해 경제적으로도 성장하고 있다.
# CPU times: user 4.62 ms, sys: 1.49 ms, total: 6.11 ms
# Wall time: 4.94 ms

# %% [markdown]
# ## SQLite Cache

# %%
from langchain_community.cache import SQLiteCache
from langchain_core.globals import set_llm_cache
import os

# 캐시 디렉토리를 생성합니다.
if not os.path.exists("cache"):
    os.makedirs("cache")

# SQLiteCache를 사용합니다.
set_llm_cache(SQLiteCache(database_path="cache/llm_cache.db"))

# %%
# %%time 
# 체인을 실행합니다.
response = chain.invoke({"country": "한국"})
print(response.content)
# Out:
# 한국은 동아시아에 위치한 고대 문명 국가로, 전통적인 문화와 현대화가 공존하는 나라이다. 경제적으로는 세계 10대 경제국 중 하나로 발전하였고, K-pop, 드라마, 영화 등의 한류 콘텐츠로 세계적으로 인기를 끌고 있다. 또한 한국은 전 세계적으로 유명한 기업들을 많이 보유하고 있으며, IT 기술과 자동차 산업 등에서 세계적인 성과를 거두고 있다. 정치적으로는 분단된 국가로, 북한과의 관계가 중요한 이슈로 남아있다. 한국은 아름다운 자연경관, 다채로운 음식 문화, 역사적인 유적지 등 다양한 매력을 지니고 있는 나라이다.
# CPU times: user 3.94 ms, sys: 942 μs, total: 4.89 ms
# Wall time: 4.35 ms
